# %%
import pandas as pd
#import fiora.IO.mgfReader as mgfReader
import matplotlib.pyplot as plt

# %% [markdown]
# # Functions

# %% [markdown]
# ## Name processing
#
# For combined dataset
# - Process well names
# - Find well belonging

# %%
def process_col_names(df, cut_off):
    msms=df.copy()
    col=msms.columns
    new=[]
    for name in col:
        if "5_P" in name:
            new_name=name[5:9].replace("-","0").strip("_")
            msms[name] = msms[name].apply(lambda x: x if x > cut_off else 0 )
            if len(new_name)==4:
                if new_name[-1]=="0": 
                    new_name=new_name.replace("0","")
                    new_name=new_name+"0"
                    new.append(new_name)
                else:
                    new.append(new_name.replace("0",""))
            else:
                new.append(new_name)
        else:
            new.append(name)
    
    msms.columns=new
    return msms

# %%
def add_id(df):
    c=0
    msms=df.copy()
    msms["Well"]=None
    for i, name in enumerate (msms.index):
        value=list(msms.iloc[i,12:-1])
        if value.count(0) ==len(msms.iloc[i,12:-1])-1:
            df=msms.iloc[i,12:-1]
            msms.loc[name,"Well"]=(str(df.loc[~(df==0)].index.values).strip("[").strip("]")[1:-1])
            c=c+1

        else:
            msms.loc[i,"Well"]="Nan"
    print("Number of mz found in just one sample: ",c )
    msms_filtered=msms[msms["Well"]!="Nan"]
    return msms_filtered

# %% [markdown]
# ## Find closest match

# %%
def find_closest(numbers, target):
    return min(numbers, key=lambda x: abs(x- target))

def find_match(numbers,target, ppm):
    closest=find_closest(numbers, target)
  
    if abs(closest-target)<target*ppm*10**-6:
        return closest

def count_matches(data,msms_list,target_list,ppm):
    data=data.copy()
    match=[]
    not_found=[]
    target_mass=target_list["Exact Mass"]
    target_smiles=target_list["SMILES"]
    target_INCHIKEY=target_list["INCHIKEY"]
    target_name=target_list["Sample Name"]
    for i in target_list.index:
        m=find_match(msms_list,target_mass[i],ppm)
        if m:
            match.append(target_mass[i])
            j=data.index[data['PEPMASS']==m].tolist()
            
            data.loc[j,"Target"]=float(target_mass[i])
            data.loc[j,"SMILES"]=target_smiles[i]
            data.loc[j,"INCHIKEY"]=target_INCHIKEY[i]
            data.loc[j,"Name"]=target_name[i]
            
           
        else:
            not_found.append(target_mass[i])
    #print(data.dropna(subset="Target").sort_values("Target"))
    print("Found", len(match), "/", len(target_mass), "matches at", ppm,"ppm")
    return match,not_found,data

# %% [markdown]
# ## Match one well

# %%
def match_one_well(df,well,ppm):

    target_data=well
    
    
    print("----- Targeting", target_data)
    
    #Sort out target
    target_list=values_df[values_df["Position"]==target_data.split()[0]]
    
    internal_s=pd.read_csv("../Tims_tof_första_plattan/internal_standards.csv", sep=";")
    #internal_s=internal_s["Exact Mass"]
    
    #Get list of found values in MetaboScape
    data_in=df[df["Well"]==target_data]
    msms_list=data_in["PEPMASS"]
    
    
    match,not_found,data_out=count_matches(data_in,msms_list,target_list,ppm)
    print("Internal Standard")
    i_match,i_not_found=count_matches(data_in,msms_list,internal_s,ppm)[0:-1]
    return match,not_found,i_match,i_not_found,data_out

# %% [markdown]
# ## Plot

# %%
def plot_findings(well, ppm):
    fig,ax=plt.subplots(1,3, figsize=(20,7),sharey=True, sharex=True)
    
    match,not_found,i_match,i_not_found=match_one_well(msms,well,ppm)[0:4]
    x_multi = [n for n in [i_match, i_not_found, match, not_found]]
    
    ax[0].hist(x_multi, 20, histtype='bar',label=["Internal standard found","Internal standard missing","Target found","Target missing"])
    ax[0].legend()
    ax[0].set_title("Found "+ str(len(match)) +" matches for combined well analysis")
    ax[0].set_xlabel("Target M")
    
    match,not_found,i_match,i_not_found=match_one_well(msms_old,well,ppm)[0:4]
    x_multi = [n for n in [i_match, i_not_found, match, not_found]]
    
    ax[1].hist(x_multi, 20, histtype='bar',label=["Internal standard found","Internal standard missing","Target found","Target missing"])
    ax[1].legend()
    ax[1].set_title("Found "+ str(len(match)) +" matches for combined well analysis, first run")
    ax[1].set_xlabel("Target M")
    
    
    path="../Tims_tof_första_plattan/Exported data/"+well+"/" + well + ".msmsonly.csv"
    msms_one=pd.read_csv(path)
    print("----- Targeting", well)
    target_list=values_df[values_df["Position"]==well.split()[0]]
    internal_s=pd.read_csv("../Tims_tof_första_plattan/internal_standards.csv", sep=";")
    
    match,not_found,data_out=count_matches(msms_one,msms_one["PEPMASS"],target_list,ppm)
    print("Internal Standard")
    
    i_match,i_not_found=count_matches(msms_one,msms_one["PEPMASS"],internal_s,ppm)[0:-1]
    x_multi = [n for n in [i_match, i_not_found, match, not_found]]
    
    ax[2].hist(x_multi, 20, histtype='bar',label=["Internal standard found","Internal standard missing","Target found","Target missing"])
    ax[2].legend()
    ax[2].set_title("Found "+ str(len(match)) +" matches for single well analysis")
    ax[2].set_xlabel("Target M")
    fig.suptitle(well + " at tolerance "+str( ppm)+"ppm", fontsize=20)

# %%
def plot_match_and_error(msms, well,ppm):
    fig,ax=plt.subplots(1,2,figsize=(12, 5))
    
    match,not_found,i_match,i_not_found,data_out=match_one_well(msms,well,ppm)
    x_multi = [n for n in [i_match, i_not_found, match, not_found]]
    
    ax[0].hist(x_multi, 20, histtype='bar',label=["Internal standard found","Internal standard missing","Target found","Target missing"])
    ax[0].legend()
    ax[0].set_title( str(len(match)) +" matches")
    ax[0].set_xlabel("Target M")
    
    data=data_out.dropna(subset="Target")
    ax[1].scatter(data["Target"],data["PEPMASS"]-data["Target"])
    ax[1].set_ylabel("Diff in Da")
    ax[1].set_xlabel("Target M")
    ax[1].set_title("Diff at "+str(ppm)+"ppm")
    ax[1].axhline(y=0, color='r', linestyle='-')

# %% [markdown]
# # Find matches

# %%
values_df=pd.read_csv("../Tims_tof_första_plattan/first_plate_targets.csv", sep=";")
#msms_recu=pd.read_csv("first_plate/Exported_data/A01-B23_recursive_fitting/A01-B23.msmsonly.csv")
msms_old=pd.read_csv("../Tims_tof_första_plattan/Exported data/A01-B23/A01-B23.msmsonly.csv")
msms=pd.read_csv("../New_run/A01-C24.msmsonly.csv")
msms=process_col_names(msms,2000)

#### Special as 3 A01 was present"
cols=list(range(1,74))
cols.remove(12)
cols.remove(13)

msms=msms.iloc[:,cols]
############

msms_old=process_col_names(msms_old, 2000)

msms=add_id(msms)
msms_old=add_id(msms_old)
# Out:
# C:\Users\klds816\AppData\Local\Temp\ipykernel_6964\922765280.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   values_df=pd.read_csv("../Tims_tof_första_plattan/first_plate_targets.csv", sep=";")
# Number of mz found in just one sample:  9166
# Number of mz found in just one sample:  11175

# %% [markdown]
# ## Plot matches for specific well

# %%
plot_findings(well="A14",ppm=10)
# Out:
# ----- Targeting A14
# Found 36 / 94 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A14
# Found 9 / 94 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A14
# Found 39 / 94 matches at 10 ppm
# Internal Standard
# Found 1 / 4 matches at 10 ppm

# %% [markdown]
# ## Run through all wells

# %%
tot=0
for well in msms["Well"].unique():
    match,not_found,i_match,i_not_found=match_one_well(msms,well,10)[0:4]
    tot=tot+len(match)
print("A total of ", tot, "matches")
# Out:
# ----- Targeting C06
# Found 9 / 96 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B11
# Found 45 / 94 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B21
# Found 39 / 95 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting C12
# Found 43 / 95 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A07
# Found 38 / 97 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A24
# Found 43 / 91 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B12
# Found 44 / 97 matches at 10 ppm
# Internal Standard
# Found 1 / 4 matches at 10 ppm
# ----- Targeting B03
# Found 11 / 89 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A09
# Found 14 / 90 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B10
# Found 8 / 92 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B18
# Found 11 / 98 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A16
# Found 16 / 95 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting C08
# Found 10 / 90 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B02
# Found 13 / 98 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting C10
# Found 40 / 92 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B16
# Found 16 / 95 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B22
# Found 7 / 92 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting C02
# Found 10 / 93 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B04
# Found 42 / 96 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B19
# Found 37 / 97 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A05
# Found 40 / 96 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B07
# Found 46 / 93 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B20
# Found 14 / 96 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A14
# Found 36 / 94 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B13
# Found 46 / 98 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B08
# Found 39 / 94 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting C03
# Found 26 / 89 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A23
# Found 42 / 93 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A19
# Found 41 / 98 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B15
# Found 48 / 98 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A22
# Found 43 / 94 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B01
# Found 22 / 93 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B14
# Found 47 / 96 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A02
# Found 43 / 97 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A03
# Found 32 / 92 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A13
# Found 45 / 94 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B05
# Found 15 / 93 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting C11
# Found 7 / 93 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting C07
# Found 45 / 96 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A21
# Found 9 / 93 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting C04
# Found 32 / 94 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B09
# Found 35 / 93 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A08
# Found 50 / 98 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A18
# Found 51 / 91 matches at 10 ppm
# Internal Standard
# Found 1 / 4 matches at 10 ppm
# ----- Targeting B23
# Found 36 / 98 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting C09
# Found 40 / 93 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A20
# Found 41 / 89 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting C01
# Found 44 / 90 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B24
# Found 56 / 93 matches at 10 ppm
# Internal Standard
# Found 1 / 4 matches at 10 ppm
# ----- Targeting A10
# Found 46 / 96 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A11
# Found 39 / 98 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B06
# Found 37 / 90 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting B17
# Found 49 / 93 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A17
# Found 36 / 94 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A04
# Found 35 / 93 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A12
# Found 39 / 92 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting C05
# Found 39 / 94 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A15
# Found 39 / 95 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# ----- Targeting A06
# Found 40 / 94 matches at 10 ppm
# Internal Standard
# Found 0 / 4 matches at 10 ppm
# A total of  1966 matches

# %% [markdown]
# ## Combine single datafiles

# %%
data_combined=pd.DataFrame(columns=msms.columns)
ppm=20
well_list=['A02', 'A03', 'A04', 'A05', 'A06', 'A07', 'A08', 'A09', 'A10', 'A11', 'A12', 'A13', 'A14']
for well in well_list:#['A06', 'A03', 'A04', 'A05', 'A06', 'A07', 'A08', 'A09', 'A10']:#msms["Well"].unique():
    data_out=match_one_well(msms,well,ppm)[4]
    data_combined=pd.concat([data_combined,data_out])
print("A total of ", tot, "matches")   

data_combined_old=pd.DataFrame(columns=msms.columns)

for well in well_list :#['A06', 'A03', 'A04', 'A05', 'A06', 'A07', 'A08', 'A09', 'A10']:#msms_old["Well"].unique():
    data_out=match_one_well(msms_old,well,ppm)[4]
    data_combined_old=pd.concat([data_combined_old,data_out])
print("A total of ", tot, "matches")   


data_combined_single=pd.DataFrame(columns=msms.columns)
for well in well_list:

    path="../Tims_tof_första_plattan/Exported data/"+well+"/" + well + ".msmsonly.csv"
    msms_one=pd.read_csv(path)
    print("----- Targeting", well)
    target_list=values_df[values_df["Position"]==well.split()[0]]

    match,not_found,data_out=count_matches(msms_one,msms_one["PEPMASS"],target_list,ppm)
    data_combined_single=pd.concat([data_combined_single,data_out])
# Out:
# ----- Targeting A02
# Found 44 / 97 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A03
# Found 35 / 92 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A04
# C:\Users\klds816\AppData\Local\Temp\ipykernel_6964\1636002607.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_combined=pd.concat([data_combined,data_out])
# Found 35 / 93 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A05
# Found 41 / 96 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A06
# Found 41 / 94 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A07
# Found 38 / 97 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A08
# Found 51 / 98 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A09
# Found 27 / 90 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A10
# Found 46 / 96 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A11
# Found 39 / 98 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A12
# Found 40 / 92 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A13
# Found 45 / 94 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A14
# Found 39 / 94 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# A total of  1966 matches
# ----- Targeting A02
# Found 4 / 97 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A03
# Found 2 / 92 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A04
# Found 1 / 93 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A05
# C:\Users\klds816\AppData\Local\Temp\ipykernel_6964\1636002607.py:13: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_combined_old=pd.concat([data_combined_old,data_out])
# Found 1 / 96 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A06
# Found 9 / 94 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A07
# Found 12 / 97 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A08
# Found 8 / 98 matches at 20 ppm
# Internal Standard
# Found 2 / 4 matches at 20 ppm
# ----- Targeting A09
# Found 13 / 90 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A10
# Found 10 / 96 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A11
# Found 16 / 98 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A12
# Found 10 / 92 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A13
# Found 15 / 94 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# ----- Targeting A14
# Found 11 / 94 matches at 20 ppm
# Internal Standard
# Found 0 / 4 matches at 20 ppm
# A total of  1966 matches
# ----- Targeting A02
# Found 16 / 97 matches at 20 ppm
# ----- Targeting A03
# Found 4 / 92 matches at 20 ppm
# ----- Targeting A04
# Found 5 / 93 matches at 20 ppm
# C:\Users\klds816\AppData\Local\Temp\ipykernel_6964\1636002607.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_combined_single=pd.concat([data_combined_single,data_out])
# ----- Targeting A05
# Found 3 / 96 matches at 20 ppm
# ----- Targeting A06
# Found 32 / 94 matches at 20 ppm
# ----- Targeting A07
# Found 50 / 97 matches at 20 ppm
# ----- Targeting A08
# Found 29 / 98 matches at 20 ppm
# ----- Targeting A09
# Found 54 / 90 matches at 20 ppm
# ----- Targeting A10
# Found 27 / 96 matches at 20 ppm
# ----- Targeting A11
# Found 54 / 98 matches at 20 ppm
# ----- Targeting A12
# Found 20 / 92 matches at 20 ppm
# ----- Targeting A13
# Found 79 / 94 matches at 20 ppm
# ----- Targeting A14
# Found 55 / 94 matches at 20 ppm

# %% [markdown]
# ## Plot differance from target

# %%
data=data_combined_single.dropna(subset="Target")

fig,ax=plt.subplots(1,3,figsize=(20, 10), sharey=True, sharex=True)
ax[0].scatter(data["Target"],data["PEPMASS"]-data["Target"])
ax[0].set_ylabel("Diff in Da")
ax[0].set_xlabel("Target M")
ax[0].set_title("Single wells first run")
ax[0].axhline(y=0, color='r', linestyle='-')

data=data_combined_old.dropna(subset="Target")
#fig = plt.figure(figsize=(10, 10))

ax[1].scatter(data["Target"],data["PEPMASS"]-data["Target"])
ax[1].set_ylabel("Diff in Da")
ax[1].set_xlabel("Target M")
ax[1].set_title("Combined wells first run ")
ax[1].axhline(y=0, color='r', linestyle='-')
#fig.suptitle("Well A02 to A10")


data=data_combined.dropna(subset="Target")
#fig = plt.figure(figsize=(10, 10))

ax[2].scatter(data["Target"],data["PEPMASS"]-data["Target"])
ax[2].set_ylabel("Diff in Da")
ax[2].set_xlabel("Target M")
ax[2].set_title("Combined wells new run")
ax[2].axhline(y=0, color='r', linestyle='-')
fig.suptitle("Wells "+str(well_list).strip("[").strip("]")+" at "+ str(ppm)+"ppm")
# Out:
# Text(0.5, 0.98, "Wells 'A02', 'A03', 'A04', 'A05', 'A06', 'A07', 'A08', 'A09', 'A10', 'A11', 'A12', 'A13', 'A14' at 20ppm")

# %%
well="B23"
plot_match_and_error(msms,well,1000)
print("First run")
plot_match_and_error(msms_old,well,1000)
# Out:
# ----- Targeting B23
# Found 45 / 98 matches at 1000 ppm
# Internal Standard
# Found 0 / 4 matches at 1000 ppm
# First run
# ----- Targeting B23
# Found 32 / 98 matches at 1000 ppm
# Internal Standard
# Found 0 / 4 matches at 1000 ppm

# %% [markdown]
# # Test: Merge with MS/MS
# - Preprocessing for modelling
#
#
# - Full python script exist

# %%
data_filtered=data_combined.dropna(subset="Target").iloc[:,[-1,1,2,3,4,8,-4,-3,-2]]

# %%
data_filtered.to_csv("matched_A02_B23_new.csv")

# %%
def read_rawfile(input_df):
    df_mgf = mgfReader.read(input_df)
    df = pd.DataFrame(df_mgf)
    return df
spectrum=read_rawfile("first_plate/Exported_data/A01_B23_no_recursive_fitting/A01-B23.gnps.mgf")

# %%
spectrum["FEATURE_ID"]=spectrum["FEATURE_ID"].astype(int)
    
df=spectrum.merge(data_filtered, right_on="FEATURE_ID", left_on="FEATURE_ID", how="right")
df.columns=['SCANS', 'FEATURE_ID', 'PrecursorMZ', 'MSLEVEL', 'CHARGE', 'POLARITY',
       'RTINMINUTES', 'Precursor_type', 'peaks', "Name", 'RT', 'PrecursorM', 'CCS','ADDUCT',
        'Target', 'SMILES','InChIKey']

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.scatter(matched_msms["Target"],matched_msms["PEPMASS"]-matched_msms["Target"])
ax.set_ylabel("Diff")
ax.set_xlabel("Target M")
ax.set_title("Target vs closest in " +target_data+" for tolerance "+str(tolerance))
ax.axhline(y=0, color='r', linestyle='-')
ax.set_ylim(-tolerance,tolerance)

# %% [markdown]
# # Process all data

# %%
# !bash full_pre_processing_combined.sh  #### Enable change directly here?
# Out:
# Working with Python 3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]
# /media/stordisk/Documents/Tims_Tof_data/match_to_target_combined_df.py:169: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   values_df= pd.read_csv(args.dir+"/"+args.target ,sep=";")
# Number of mz found in just one sample:  6122
# ----- Targeting B14
# Found 46 / 96 matches at 50.0 ppm
# Internal Standard
# Found 1 / 4 matches at 50.0 ppm
# /media/stordisk/Documents/Tims_Tof_data/match_to_target_combined_df.py:179: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_combined=pd.concat([data_combined,data_out])
# ----- Targeting B22
# Found 54 / 92 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting B12
# Found 47 / 97 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting B02
# Found 52 / 98 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A20
# Found 20 / 89 matches at 50.0 ppm
# Internal Standard
# Found 1 / 4 matches at 50.0 ppm
# ----- Targeting B11
# Found 54 / 94 matches at 50.0 ppm
# Internal Standard
# Found 1 / 4 matches at 50.0 ppm
# ----- Targeting A16
# Found 20 / 95 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A21
# Found 51 / 93 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting B08
# Found 2 / 94 matches at 50.0 ppm
# Internal Standard
# Found 1 / 4 matches at 50.0 ppm
# ----- Targeting A14
# Found 46 / 94 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting B16
# Found 48 / 95 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A15
# Found 28 / 95 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A03
# Found 19 / 92 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting B09
# Found 50 / 93 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting B21
# Found 46 / 95 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A08
# Found 45 / 98 matches at 50.0 ppm
# Internal Standard
# Found 1 / 4 matches at 50.0 ppm
# ----- Targeting B18
# Found 63 / 98 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A05
# Found 47 / 96 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting B23
# Found 57 / 98 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A22
# Found 59 / 94 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A02
# Found 53 / 97 matches at 50.0 ppm
# Internal Standard
# Found 1 / 4 matches at 50.0 ppm
# ----- Targeting B20
# Found 57 / 96 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A10
# Found 42 / 96 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A06
# Found 38 / 94 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting B19
# Found 44 / 97 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting B06
# Found 56 / 90 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A23
# Found 61 / 93 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting B15
# Found 48 / 98 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A24
# Found 54 / 91 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting B04
# Found 57 / 96 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting B13
# Found 33 / 98 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A11
# Found 59 / 98 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A13
# Found 59 / 94 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A04
# Found 28 / 93 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A07
# Found 46 / 97 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting B05
# Found 44 / 93 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A18
# Found 37 / 91 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A09
# Found 42 / 90 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting B17
# Found 42 / 93 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A19
# Found 53 / 98 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A17
# Found 39 / 94 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting B07
# Found 54 / 93 matches at 50.0 ppm
# Internal Standard
# Found 1 / 4 matches at 50.0 ppm
# ----- Targeting B01
# Found 40 / 93 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting A12
# Found 32 / 92 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# ----- Targeting B10
# Found 42 / 92 matches at 50.0 ppm
# Internal Standard
# Found 0 / 4 matches at 50.0 ppm
# Saving as A01-B23_matched_new.csv
# Working with Python 3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]
# Removing  33 / 2015 due to precursor out of spec
# Successfully interpreted 1982 from 1982 entries. Dropping the rest.
# Checking if main layer InChI-Keys are correct. Result: confirmed! (1.000 correct)
# Dropping all other.
# Distinguish CE absolute values (eV - float) and normalized CE (in % - str format)
# Detected 1 unique collision energies in range from 20.0 to 20.0 eV
# Total number of uniquely matched peaks: 33879 , conflicts found within 4308 matches (11.28 %))
# Total number of conflicting peak to fragment matches: 4308
# Found 1926 unique molecular structures.
# > Processing precursors
# 1 found with misaligned precursor. Removing these.
# ---------- Number of matched MS/MS spectrum:  1928 --------------
# Saving as test_A01_B23_processed_new.csv

# %% [markdown]
# # Train model

# %%
! cd ../'MS models'/fiora/notebooks/
# !python ../'MS models'/fiora/notebooks/train_model_test.py -i test_A01_B23_processed_new.csv -l 0.00005 -e 100 -t "test_new_mona_tuned" -m ../checkpoint_Mona_only.best.pt
# Out:
# [14:23:33] WARNING: not removing hydrogen atom without neighbors
# [14:23:33] WARNING: not removing hydrogen atom without neighbors
# [14:23:33] WARNING: not removing hydrogen atom without neighbors
# Working with Python 3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]
# Filtering based on CE and weight
# Filtering spectra (1928) down to 1928
# Filtering low peak counts
# Removed  104 due to less then 2 peaks
# Split into training, testing and validation
# Running on device: cuda:0
# Training model
# dataset
# test           183
# train         1456
# validation     183
# Name: group_id, dtype: int64
# Prepared training/validation with 1641 data points
# Using pre-arranged train/validation set
# /home/michaelah/miniconda3/envs/fiora/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: FutureWarning: The default value for `maximize` will be changed from `True` to `None` in v1.7.0 of TorchMetrics,will automatically infer the value based on the `higher_is_better` attribute of the metric (if such attribute exists) or raise an error if it does not. If you are explicitly setting the `maximize` argument to either `True` or `False` already, you can ignore this warning.
#   warnings.warn(*args, **kwargs)  # noqa: B028
# /home/michaelah/miniconda3/envs/fiora/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 	Validation RMSE: 0.019829
# 	 >> Set new checkpoint to epoch 3
# 	Validation RMSE: 0.019013
# 	 >> Set new checkpoint to epoch 6
# 	Validation RMSE: 0.018807
# 	 >> Set new checkpoint to epoch 9
# 	Validation RMSE: 0.0186200
# 	 >> Set new checkpoint to epoch 12
# 	Validation RMSE: 0.0184193
# 	 >> Set new checkpoint to epoch 15
# 	Validation RMSE: 0.0186186
# 	Validation RMSE: 0.0185180
# 	Validation RMSE: 0.0192173
# 	Validation RMSE: 0.0191169
# 	Validation RMSE: 0.0198163
# 	Validation RMSE: 0.0200157
# 	Validation RMSE: 0.0196154
# 	Validation RMSE: 0.0198150
# 	Validation RMSE: 0.0210145
# 	Validation RMSE: 0.0199145
# 	Validation RMSE: 0.0204143
# 	Validation RMSE: 0.0202140
# 	Validation RMSE: 0.0202139
# 	Validation RMSE: 0.0205138
# 	Validation RMSE: 0.0204136
# 	Validation RMSE: 0.0202135
# 	Validation RMSE: 0.0207136
# 	Validation RMSE: 0.0205132
# 	Validation RMSE: 0.0204133
# 	Validation RMSE: 0.0203129
# 	Validation RMSE: 0.0205130
# 	Validation RMSE: 0.0205128
# 	Validation RMSE: 0.0206129
# 	Validation RMSE: 0.0206128
# 	Validation RMSE: 0.0208127
# 	Validation RMSE: 0.0208127
# 	Validation RMSE: 0.0207129
# 	Validation RMSE: 0.0206124
# Finished Training!SE: 0.0126
# {'epoch': 15, 'val_loss': 0.00033907886245287955, 'file': '../../checkpoint_test_new_mona_tuned.best.pt'}
# Median  spectral_sqrt_cosine for the test set is 0.853385733568296
