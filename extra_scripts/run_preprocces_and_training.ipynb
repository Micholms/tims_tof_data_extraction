# %% [markdown]
# # Full pre-proccessing and training loop

# %%
# !python match_to_target_combined_df.py -d first_plate -t first_plate_targets.csv -i A01-B23 -p 50 -o A01-B23_combined_matched.csv
# Out:
# Working with Python 3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]
# /media/stordisk/Documents/Tims_Tof_data/match_to_target_combined_df.py:73: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   values_df= pd.read_csv(args.dir+"/"+args.target ,sep=";")
# Number of mz found in just one sample:  6122
# ----- Targeting B14
# Found 46 / 96 matches at 50.0 ppm
# Internal Standard
# Found 1 / 4 matches at 50.0 ppm
# /media/stordisk/Documents/Tims_Tof_data/match_to_target_combined_df.py:83: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_combined=pd.concat([data_combined,data_out])
# ----- Targeting B22
# Found 54 / 92 matches at 50.0 ppm
# ...

# %%
# !python filter_data.py -i A01-B23_combined_matched.csv -o A01_B23_processed_combined.csv

#Use for traning
# Out:
# Working with Python 3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]
# Removing  33 / 2015 due to precursor out of spec
# Successfully interpreted 1982 from 1982 entries. Dropping the rest.
# Checking if main layer InChI-Keys are correct. Result: confirmed! (1.000 correct)
# Dropping all other.
# Distinguish CE absolute values (eV - float) and normalized CE (in % - str format)
# Detected 1 unique collision energies in range from 20.0 to 20.0 eV
# Total number of uniquely matched peaks: 33879 , conflicts found within 4308 matches (11.28 %))
# Total number of conflicting peak to fragment matches: 4308
# Found 1926 unique molecular structures.
# > Processing precursors
# 1 found with misaligned precursor. Removing these.
# ---------- Number of matched MS/MS spectrum:  1928 --------------
# Saving as A01_B23_processed_combined.csv

# %%
# !python ../'MS models'/fiora/notebooks/train_model_test.py -i processed_data/test_A01_B23_processed_new.csv -l 0.00005 -e 100 -t "test_new_mona_tuned" -m ../checkpoint_Mona_only.best.pt
# Out:
# [10:18:54] WARNING: not removing hydrogen atom without neighbors
# [10:18:54] WARNING: not removing hydrogen atom without neighbors
# [10:18:54] WARNING: not removing hydrogen atom without neighbors
# Working with Python 3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]
# Filtering based on CE and weight
# Filtering spectra (1928) down to 1928
# Filtering low peak counts
# Removed  104 due to less then 2 peaks
# Split into training, testing and validation
# Running on device: cuda:0
# Training model
# dataset
# test           183
# train         1456
# validation     183
# Name: group_id, dtype: int64
# Prepared training/validation with 1641 data points
# Using pre-arranged train/validation set
# ...

# %% [markdown]
# ## For one well at a time

# %%
! bash full_pre_processing.sh
! rm *10.0_matched.csv
# Out:
# Working with Python 3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]
# /media/stordisk/Documents/Tims_Tof_data/match_to_target.py:29: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   values_df=  pd.read_csv(args.target ,sep=";")
# Targeting A01
# Found 37 / 96 matches at 10.0 ppm
# Saving as A01_10.0_matched.csv
# Working with Python 3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]
# /media/stordisk/Documents/Tims_Tof_data/match_to_target.py:29: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   values_df=  pd.read_csv(args.target ,sep=";")
# Targeting A01-B23
# Found 0 / 0 matches at 10.0 ppm
# Traceback (most recent call last):
#   File "/media/stordisk/Documents/Tims_Tof_data/match_to_target.py", line 47, in <module>
#     matched_msms=data_out.dropna(subset="Target").sort_values("Target")
# ...
